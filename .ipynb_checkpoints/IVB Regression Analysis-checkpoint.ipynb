# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import statsmodels.api as sm
import patsy

# %%
games = os.listdir('YakkertechData')[:-4]
dflst = []
for game in games:
    dflst.append(pd.read_csv(os.path.join('YakkertechData', game)))
allgamedata = pd.concat(dflst)
allgamedata
# Out:
#    PitchNo        Date        Time PAofInning PitchofPA          Pitcher  \
# 0        1  01/20/2023  1:03:24 PM          1         1  Nolan Mccracken
# 1        2  01/20/2023  1:03:52 PM          1         2  Nolan Mccracken
# 2        3  01/20/2023  1:04:12 PM          1         3  Nolan Mccracken
# 3        4  01/20/2023  1:04:34 PM          2         1  Nolan Mccracken
# 4        5  01/20/2023  1:05:06 PM          2         2  Nolan Mccracken
# ..     ...         ...         ...        ...       ...              ...
# 74      75  11/16/2022  9:22:22 AM          2         3  Zachary Ernisse
# 75      76  11/16/2022  9:22:50 AM          3         1  Zachary Ernisse
# 76      77  11/16/2022  9:23:04 AM          3         2  Zachary Ernisse
# 77      78  11/16/2022  9:23:18 AM          3         3  Zachary Ernisse
# 78      79  11/16/2022  9:33:56 AM          1         1  Zachary Ernisse
#
#     PitcherId PitcherThrows   PitcherTeam         Batter  ...  \
# 0   mccrano42         Right  Uc san diego  Bradlee Preap  ...
# 1   mccrano42         Right  Uc san diego  Bradlee Preap  ...
# 2   mccrano42         Right  Uc san diego  Bradlee Preap  ...
# 3   mccrano42         Right  Uc san diego  Bradlee Preap  ...
# 4   mccrano42         Right  Uc san diego      Ben Pajak  ...
# ..        ...           ...           ...            ...  ...
# 74        NaN          Left  Uc san diego  Crew Robinson  ...
# 75        NaN          Left  Uc san diego  Brock Kleszcz  ...
# 76        NaN          Left  Uc san diego  Brock Kleszcz  ...
# 77        NaN          Left  Uc san diego  Brock Kleszcz  ...
# 78        NaN          Left  Uc san diego  Jalen Fejeran  ...
#
#    yt_HitSpinConfidence yt_EffectiveBattingSpeed yt_ReleaseAccuracy  \
# 0                   NaN                      NaN               high
# 1                   NaN                      NaN               high
# 2                   NaN                      NaN               high
# 3                   NaN                      NaN               high
# 4                   NaN                      NaN               high
# ..                  ...                      ...                ...
# 74                  NaN                35.545796               high
# 75                  NaN                      NaN               high
# 76                  NaN                      NaN               high
# 77                  NaN                      NaN               high
# 78                  NaN                      NaN                NaN
#
#    yt_ZoneAccuracy yt_SeamLat yt_SeamLong yt_ReleaseDistance Catcher  \
# 0             high  16.649588  -23.315828          53.231277     NaN
# 1             high  11.755224   -3.302182          53.335639     NaN
# 2             high  27.008184  -71.725414          53.508536     NaN
# 3             high  40.351346   -15.92502          53.451727     NaN
# 4             high  44.363811    57.32922          53.270835     NaN
# ..             ...        ...         ...                ...     ...
# 74            high        NaN         NaN          54.252345     NaN
# 75             low        NaN         NaN          54.295606     NaN
# 76            high        NaN         NaN          54.309256     NaN
# 77            high        NaN         NaN          54.171285     NaN
# 78             NaN        NaN         NaN                NaN     NaN
#
#    CatcherId CatcherTeam
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN
# ..       ...         ...
# 74       NaN         NaN
# 75       NaN         NaN
# 76       NaN         NaN
# 77       NaN         NaN
# 78       NaN         NaN
#
# [14329 rows x 124 columns]

# %%
allFB = allgamedata[allgamedata.TaggedPitchType == 'Fastball']
allFB = allFB[['PitcherThrows', 'InducedVertBreak', 'VertBreak', 'yt_Efficiency', 'SpinRate', 'Tilt', 'SpinAxis', 'RelSpeed', 'Extension', 'yt_GyroSpin']]
allFB = allFB.dropna()
allFB
# Out:
#    PitcherThrows InducedVertBreak  VertBreak yt_Efficiency     SpinRate  \
# 0          Right         15.39505 -15.225392     95.698067  2243.318786
# 1          Right        16.128602 -13.920308     94.001842  2331.242797
# 4          Right        15.309531 -14.720538     96.571451  2267.534131
# 7          Right        15.150609 -15.166215     96.021025  2268.054005
# 9          Right        15.560563 -15.003616      90.68013  2333.037235
# ..           ...              ...        ...           ...          ...
# 52         Right        14.135811 -18.121188     98.936835  2127.864821
# 63         Right         15.17802 -16.649501     96.392116  2250.741728
# 69          Left        14.034552 -20.771267     99.599001  1952.257876
# 70          Left         14.15857 -19.962815     99.003777  1933.897393
# 72          Left        14.288875 -21.147453     99.763101  1830.152557
#
#      Tilt    SpinAxis   RelSpeed Extension yt_GyroSpin
# 0   12:45  203.456409  93.181195  7.268723 -650.902744
# 1   12:30  197.571868  94.325621  7.164361 -795.242167
# 4   12:45  204.779323  93.436131  7.229165  -588.66639
# 7   12:45  205.624413  93.044028  7.239898 -633.417894
# 9   12:45  201.631627  93.545168  7.130828 -983.511218
# ..    ...         ...        ...       ...         ...
# 52   1:15  214.473261  92.392651  6.574396 -309.458231
# 63   1:00   209.48167  92.254524  6.805102 -599.120213
# 69  10:45  145.862809  89.870935  6.085815 -174.657719
# 70  11:00  148.918086   91.72484   6.18387 -272.296665
# 72  11:00  150.847812  88.713619  6.070597  125.900202
#
# [6771 rows x 10 columns]

# %% [markdown]
# Convert Tilt into a numerical value by assigning it a number I call "tiltpoints", which represents the tilt in "minutes" instead of the "hour:minute" clock format the tilt is collected in. The tilt_from_12 function will return the magnitude of the tilt away from 12:00, or straight over the top. Lower numbers will represent tilts higher up on the clock and bigger numbers will represent tilts lower on the clock. Tilts lower than 3 or 9 will be discarded as null, as those were likely misreads, and any pitch marked with lower than 50% efficiency is taken out due to its likelihood the pitch was a higher tilt slider mistagged as a fastball

# %%
def tilt_from_12(tilt):
    colonpos = tilt.find(':')
    hour = tilt[:colonpos]
    minute = tilt[colonpos+1:]
    if hour == '9':
        tiltpts = 180 - int(minute)
    elif hour == '10':
        tiltpts = 120 - int(minute)
    elif hour == '11':
        tiltpts = 60 - int(minute)
    elif hour == '12':
        tiltpts = int(minute)
    elif hour == '1':
        tiltpts = 60 + int(minute)
    elif hour == '2':
        tiltpts = 120 + int(minute)
    else:
        tiltpts = np.nan
    return tiltpts
tiltc = allFB.Tilt.apply(tilt_from_12)
allFBclean = allFB.assign(Tilt = tiltc)
allFBclean = allFBclean[allFBclean.yt_Efficiency >= 50]
allFBclean
# Out:
#    PitcherThrows InducedVertBreak  VertBreak yt_Efficiency     SpinRate  Tilt  \
# 0          Right         15.39505 -15.225392     95.698067  2243.318786  45.0
# 1          Right        16.128602 -13.920308     94.001842  2331.242797  30.0
# 4          Right        15.309531 -14.720538     96.571451  2267.534131  45.0
# 7          Right        15.150609 -15.166215     96.021025  2268.054005  45.0
# 9          Right        15.560563 -15.003616      90.68013  2333.037235  45.0
# ..           ...              ...        ...           ...          ...   ...
# 52         Right        14.135811 -18.121188     98.936835  2127.864821  75.0
# 63         Right         15.17802 -16.649501     96.392116  2250.741728  60.0
# 69          Left        14.034552 -20.771267     99.599001  1952.257876  75.0
# 70          Left         14.15857 -19.962815     99.003777  1933.897393  60.0
# 72          Left        14.288875 -21.147453     99.763101  1830.152557  60.0
#
#       SpinAxis   RelSpeed Extension yt_GyroSpin
# 0   203.456409  93.181195  7.268723 -650.902744
# 1   197.571868  94.325621  7.164361 -795.242167
# 4   204.779323  93.436131  7.229165  -588.66639
# 7   205.624413  93.044028  7.239898 -633.417894
# 9   201.631627  93.545168  7.130828 -983.511218
# ..         ...        ...       ...         ...
# 52  214.473261  92.392651  6.574396 -309.458231
# 63   209.48167  92.254524  6.805102 -599.120213
# 69  145.862809  89.870935  6.085815 -174.657719
# 70  148.918086   91.72484   6.18387 -272.296665
# 72  150.847812  88.713619  6.070597  125.900202
#
# [6722 rows x 10 columns]

# %%
allFBclean.rename(columns = {'InducedVertBreak':'IVB', 'VertBreak':'VB', 'yt_Efficiency':'Efficiency', 
                             'SpinRate':'SpinRate', 'Tilt':'Tilt', 'SpinAxis':'SpinAxis', 
                             'RelSpeed': 'Velocity', 'Extension': 'Extension', 'yt_GyroSpin': 'GyroSpin'}, 
                  inplace = True)
allFBclean
# Out:
#    PitcherThrows        IVB         VB Efficiency     SpinRate  Tilt  \
# 0          Right   15.39505 -15.225392  95.698067  2243.318786  45.0
# 1          Right  16.128602 -13.920308  94.001842  2331.242797  30.0
# 4          Right  15.309531 -14.720538  96.571451  2267.534131  45.0
# 7          Right  15.150609 -15.166215  96.021025  2268.054005  45.0
# 9          Right  15.560563 -15.003616   90.68013  2333.037235  45.0
# ..           ...        ...        ...        ...          ...   ...
# 52         Right  14.135811 -18.121188  98.936835  2127.864821  75.0
# 63         Right   15.17802 -16.649501  96.392116  2250.741728  60.0
# 69          Left  14.034552 -20.771267  99.599001  1952.257876  75.0
# 70          Left   14.15857 -19.962815  99.003777  1933.897393  60.0
# 72          Left  14.288875 -21.147453  99.763101  1830.152557  60.0
#
#       SpinAxis   Velocity Extension    GyroSpin
# 0   203.456409  93.181195  7.268723 -650.902744
# 1   197.571868  94.325621  7.164361 -795.242167
# 4   204.779323  93.436131  7.229165  -588.66639
# 7   205.624413  93.044028  7.239898 -633.417894
# 9   201.631627  93.545168  7.130828 -983.511218
# ..         ...        ...       ...         ...
# 52  214.473261  92.392651  6.574396 -309.458231
# 63   209.48167  92.254524  6.805102 -599.120213
# 69  145.862809  89.870935  6.085815 -174.657719
# 70  148.918086   91.72484   6.18387 -272.296665
# 72  150.847812  88.713619  6.070597  125.900202
#
# [6722 rows x 10 columns]

# %% [markdown]
# Very messy data - lots of observations that don't make sense
# Solution: Choose ranges for each metric to analyze - wide enough to include all good data but narrow enough to discard outliers
# - IVB: 7"-22"
# - Efficiency: 50%-100%
# - Spin Rate: 1000rpm-3000rpm
# - Tilt: 9:00-12:00, 12:00-3:00
# - Velo: 77-100
# - Extension: 5'-8'

# %%
allFBclean = allFBclean[((allFBclean.IVB > 7) & (allFBclean.IVB < 22))
                       & ((allFBclean.get('SpinRate') > 1000) & (allFBclean.get('SpinRate') < 3000))
                       & ((allFBclean.Velocity > 77) & (allFBclean.Velocity < 100))
                       & ((allFBclean.Extension > 5) & (allFBclean.Extension < 8))]
allFBclean
# Out:
#    PitcherThrows        IVB         VB Efficiency     SpinRate  Tilt  \
# 0          Right   15.39505 -15.225392  95.698067  2243.318786  45.0
# 1          Right  16.128602 -13.920308  94.001842  2331.242797  30.0
# 4          Right  15.309531 -14.720538  96.571451  2267.534131  45.0
# 7          Right  15.150609 -15.166215  96.021025  2268.054005  45.0
# 9          Right  15.560563 -15.003616   90.68013  2333.037235  45.0
# ..           ...        ...        ...        ...          ...   ...
# 52         Right  14.135811 -18.121188  98.936835  2127.864821  75.0
# 63         Right   15.17802 -16.649501  96.392116  2250.741728  60.0
# 69          Left  14.034552 -20.771267  99.599001  1952.257876  75.0
# 70          Left   14.15857 -19.962815  99.003777  1933.897393  60.0
# 72          Left  14.288875 -21.147453  99.763101  1830.152557  60.0
#
#       SpinAxis   Velocity Extension    GyroSpin
# 0   203.456409  93.181195  7.268723 -650.902744
# 1   197.571868  94.325621  7.164361 -795.242167
# 4   204.779323  93.436131  7.229165  -588.66639
# 7   205.624413  93.044028  7.239898 -633.417894
# 9   201.631627  93.545168  7.130828 -983.511218
# ..         ...        ...       ...         ...
# 52  214.473261  92.392651  6.574396 -309.458231
# 63   209.48167  92.254524  6.805102 -599.120213
# 69  145.862809  89.870935  6.085815 -174.657719
# 70  148.918086   91.72484   6.18387 -272.296665
# 72  150.847812  88.713619  6.070597  125.900202
#
# [6505 rows x 10 columns]

# %% [markdown]
# Identify relationships between variables and IVB using scatterplots

# %%
sns.scatterplot(x = 'Efficiency', y = 'IVB', data = allFBclean)
# Out:
# <AxesSubplot:xlabel='Efficiency', ylabel='IVB'>

# %%
sns.scatterplot(x = 'SpinRate', y = 'IVB', data = allFBclean)
# Out:
# <AxesSubplot:xlabel='SpinRate', ylabel='IVB'>

# %%
sns.scatterplot(x = 'Tilt', y = 'IVB', data = allFBclean)
# Out:
# <AxesSubplot:xlabel='Tilt', ylabel='IVB'>

# %%
sns.scatterplot(x = 'SpinAxis', y = 'IVB', data = allFBclean)
# Out:
# <AxesSubplot:xlabel='SpinAxis', ylabel='IVB'>

# %%
sns.scatterplot(x = 'Velocity', y = 'IVB', data = allFBclean)
# Out:
# <AxesSubplot:xlabel='Velocity', ylabel='IVB'>

# %%
sns.scatterplot(x = 'Extension', y = 'IVB', data = allFBclean)
# Out:
# <AxesSubplot:xlabel='Extension', ylabel='IVB'>

# %%
sns.scatterplot(x = 'GyroSpin', y = 'IVB', data = allFBclean)
# Out:
# <AxesSubplot:xlabel='GyroSpin', ylabel='IVB'>

# %% [markdown]
# Features chosen for regression analysis:
# - Spin Rate
# - Spin Efficiency
# - Tilt
# - Velocity
# - Extension
# - Gyro Spin
#
# Spin Axis will not be used as it is pretty much the same metric as Tilt. Velocity and Extension show no correlation when compared to IVB in the single variable scatterplots, but they will be left in to see if there is a correlation in the multi-dimensional regression analysis

# %%
allFBcleani = allFBclean.assign(index = list(range(allFBclean.shape[0]))).set_index('index')
training = allFBcleani.sample(int(allFBclean.shape[0] * .9), random_state = 10).drop(columns = ['PitcherThrows']).astype(float)
training
# Out:
#              IVB         VB  Efficiency     SpinRate   Tilt    SpinAxis  \
# index
# 1961   12.360833 -19.105221   99.983807  2235.568697   90.0  226.770344
# 46     13.892983 -18.328394   98.806383  2223.890892   75.0  218.339638
# 3155   12.652750 -21.324222   98.824157  2015.635047   90.0  222.559647
# 1906   11.582886 -23.030173   95.026874  1832.759622   90.0  224.578331
# 1717   15.542991 -21.285562   88.918993  2085.427560   45.0  159.883854
# ...          ...        ...         ...          ...    ...         ...
# 5286   15.340696 -25.319880   87.671505  1809.158572   30.0  167.179799
# 3326   16.587424 -19.356422   98.346329  2223.818062   60.0  153.572108
# 1524   14.287798 -18.400644   89.698068  2273.026273   75.0  216.002815
# 5959   11.007018 -25.099631   89.281318  2100.836300  105.0  127.493824
# 1818    8.320082 -28.691275   98.869724  1935.067996  135.0  243.867095
#
#         Velocity  Extension     GyroSpin
# index
# 1961   92.955088   6.773421   -40.229487
# 46     91.936105   6.594098  -342.579306
# 3155   90.633628   6.592899  -308.191898
# 1906   89.701568   6.000000  -570.778302
# 1717   85.821222   6.519364   954.162936
# ...          ...        ...          ...
# 5286   82.061518   6.372736   870.223565
# 3326   88.064153   6.000000   402.750315
# 1524   92.275072   6.160811 -1004.836125
# 5959   87.162013   6.465054   946.273733
# 1818   85.875272   6.726593   290.116791
#
# [5854 rows x 9 columns]

# %%
training_i = list(training.index)
test_i = []
for i in range(allFBclean.shape[0]):
    if i not in training_i:
        test_i.append(i)
test = allFBcleani.loc[test_i].drop(columns = ['PitcherThrows']).astype(float)
test
# Out:
#              IVB         VB  Efficiency     SpinRate  Tilt    SpinAxis  \
# index
# 0      15.395050 -15.225392   95.698067  2243.318786  45.0  203.456409
# 26     17.172006 -15.981737   91.536020  2367.014683  30.0  162.784610
# 44     17.541630 -18.407861   94.461469  2191.352542  15.0  170.486198
# 55     17.435843 -19.738194   94.884724  2272.733240  30.0  161.785549
# 58     17.104069 -18.768495   97.131419  2296.454476  45.0  157.207247
# ...          ...        ...         ...          ...   ...         ...
# 6479   15.472995 -21.867666   81.622788  2039.570195  30.0  167.315366
# 6484   14.994705 -19.489639   99.618356  1973.909883  60.0  153.262156
# 6486   13.990123 -20.555092   99.926563  1963.422556  75.0  145.183050
# 6494   14.054826 -16.714210   98.985777  2157.088164  75.0  214.307433
# 6500   14.135811 -18.121188   98.936835  2127.864821  75.0  214.473261
#
#         Velocity  Extension     GyroSpin
# index
# 0      93.181195   7.268723  -650.902744
# 26     92.023183   5.908421   953.045168
# 44     88.006499   6.092073   719.161363
# 55     86.620273   6.444083   717.582627
# 58     87.984339   6.296137   546.096383
# ...          ...        ...          ...
# 6479   86.554158   5.927391  1178.321048
# 6484   88.917643   6.217463  -172.288671
# 6486   89.305961   6.378524   -75.232570
# 6494   94.743327   6.690864  -306.440120
# 6500   92.392651   6.574396  -309.458231
#
# [651 rows x 9 columns]

# %% [markdown]
# Run an OLS model on the training data, first just using all 6 independent variables

# %%
ivb, predictors = patsy.dmatrices('IVB ~ Efficiency + SpinRate + Tilt + Velocity + Extension + GyroSpin', training)
mod = sm.OLS(ivb, predictors)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    IVB   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                 1.455e+04
# Date:                Thu, 25 May 2023   Prob (F-statistic):               0.00
# Time:                        16:05:44   Log-Likelihood:                -4743.6
# No. Observations:                5854   AIC:                             9501.
# Df Residuals:                    5847   BIC:                             9548.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     15.9886      0.218     73.218      0.000      15.561      16.417
# Efficiency     0.1160      0.001    136.804      0.000       0.114       0.118
# SpinRate       0.0047    4.1e-05    114.436      0.000       0.005       0.005
# Tilt          -0.0644      0.000   -218.291      0.000      -0.065      -0.064
# Velocity      -0.1660      0.003    -62.410      0.000      -0.171      -0.161
# Extension     -0.5794      0.019    -29.867      0.000      -0.617      -0.541
# GyroSpin      -0.0003   1.07e-05    -29.097      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                      485.791   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              831.419
# Skew:                          -0.606   Prob(JB):                    2.88e-181
# Kurtosis:                       4.393   Cond. No.                     6.60e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.6e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
